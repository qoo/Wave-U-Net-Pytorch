# %%
# waveunet.py
import torch
import torch.nn as nn

from waveunet_utils import crop, Resample1d, ConvLayer

class UpsamplingBlock(nn.Module):
    def __init__(self, n_inputs, n_shortcut, n_outputs, kernel_size, stride, depth, conv_type, res):
        super(UpsamplingBlock, self).__init__()
        assert(stride > 1)

        # CONV 1 for UPSAMPLING
        if res == "fixed":
            self.upconv = Resample1d(n_inputs, 15, stride, transpose=True)
        else:
            self.upconv = ConvLayer(n_inputs, n_inputs, kernel_size, stride, conv_type, transpose=True)

        self.pre_shortcut_convs = nn.ModuleList([ConvLayer(n_inputs, n_outputs, kernel_size, 1, conv_type)] +
                                                [ConvLayer(n_outputs, n_outputs, kernel_size, 1, conv_type) for _ in range(depth - 1)])

        # CONVS to combine high- with low-level information (from shortcut)
        self.post_shortcut_convs = nn.ModuleList([ConvLayer(n_outputs + n_shortcut, n_outputs, kernel_size, 1, conv_type)] +
                                                 [ConvLayer(n_outputs, n_outputs, kernel_size, 1, conv_type) for _ in range(depth - 1)])

    def forward(self, x, shortcut):
        # UPSAMPLE HIGH-LEVEL FEATURES
        upsampled = self.upconv(x)

        for conv in self.pre_shortcut_convs:
            upsampled = conv(upsampled)

        # Prepare shortcut connection
        combined = crop(shortcut, upsampled)

        # Combine high- and low-level features
        for conv in self.post_shortcut_convs:
            combined = conv(torch.cat([combined, crop(upsampled, combined)], dim=1))
        return combined

    def get_output_size(self, input_size):
        curr_size = self.upconv.get_output_size(input_size)

        # Upsampling convs
        for conv in self.pre_shortcut_convs:
            curr_size = conv.get_output_size(curr_size)

        # Combine convolutions
        for conv in self.post_shortcut_convs:
            curr_size = conv.get_output_size(curr_size)

        return curr_size

class DownsamplingBlock(nn.Module):
    def __init__(self, n_inputs, n_shortcut, n_outputs, kernel_size, stride, depth, conv_type, res):
        super(DownsamplingBlock, self).__init__()
        assert(stride > 1)

        self.kernel_size = kernel_size
        self.stride = stride

        # CONV 1
        self.pre_shortcut_convs = nn.ModuleList([ConvLayer(n_inputs, n_shortcut, kernel_size, 1, conv_type)] +
                                                [ConvLayer(n_shortcut, n_shortcut, kernel_size, 1, conv_type) for _ in range(depth - 1)])

        self.post_shortcut_convs = nn.ModuleList([ConvLayer(n_shortcut, n_outputs, kernel_size, 1, conv_type)] +
                                                 [ConvLayer(n_outputs, n_outputs, kernel_size, 1, conv_type) for _ in
                                                  range(depth - 1)])

        # CONV 2 with decimation
        if res == "fixed":
            self.downconv = Resample1d(n_outputs, 15, stride) # Resampling with fixed-size sinc lowpass filter
        else:
            self.downconv = ConvLayer(n_outputs, n_outputs, kernel_size, stride, conv_type)

    def forward(self, x):
        # PREPARING SHORTCUT FEATURES
        shortcut = x
        for conv in self.pre_shortcut_convs:
            shortcut = conv(shortcut)

        # PREPARING FOR DOWNSAMPLING
        out = shortcut
        for conv in self.post_shortcut_convs:
            out = conv(out)

        # DOWNSAMPLING
        out = self.downconv(out)

        return out, shortcut

    def get_input_size(self, output_size):
        curr_size = self.downconv.get_input_size(output_size)

        for conv in reversed(self.post_shortcut_convs):
            curr_size = conv.get_input_size(curr_size)

        for conv in reversed(self.pre_shortcut_convs):
            curr_size = conv.get_input_size(curr_size)
        return curr_size

class Waveunet_ctc(nn.Module):
    def __init__(self, num_inputs, num_channels, num_outputs, instruments, kernel_size, target_output_size, conv_type, res, separate=False, depth=1, strides=2):
        super(Waveunet_ctc, self).__init__()

        self.num_levels = len(num_channels)
        self.strides = strides
        self.kernel_size = kernel_size
        self.num_inputs = num_inputs
        self.num_outputs = num_outputs
        self.depth = depth
        self.instruments = instruments
        self.separate = separate

        # Only odd filter kernels allowed
        assert(kernel_size % 2 == 1)

        self.waveunets = nn.ModuleDict()

        model_list = instruments if separate else ["ALL"]
        # Create a model for each source if we separate sources separately, otherwise only one (model_list=["ALL"])
        for instrument in model_list:
            module = nn.Module()

            module.downsampling_blocks = nn.ModuleList()
            module.upsampling_blocks = nn.ModuleList()
            
            print("module.downsampling_blocks.append")
            for i in range(self.num_levels - 1):
                in_ch = num_inputs if i == 0 else num_channels[i]

                module.downsampling_blocks.append(
                    DownsamplingBlock(in_ch, num_channels[i], num_channels[i+1], kernel_size, strides, depth, conv_type, res))
            
            upsampling_layer = 3
            print("module.upsampling_blocks.append")
            for i in range(0, self.num_levels - 1):
#             for i in range(0, upsampling_layer - 1):
                module.upsampling_blocks.append(
                    UpsamplingBlock(num_channels[-1-i], num_channels[-2-i], num_channels[-2-i], kernel_size, strides, depth, conv_type, res))

            module.bottlenecks = nn.ModuleList(
                [ConvLayer(num_channels[-1], num_channels[-1], kernel_size, 1, conv_type) for _ in range(depth)])

            # Output conv
            outputs = num_outputs if separate else num_outputs * len(instruments)
#             module.output_conv = nn.Conv1d(num_channels[0], outputs, 1)
            print("num_channels[0],num_channels[-2-i]",num_channels[0],num_channels[-2-i])
            module.output_conv = nn.Conv1d(num_channels[-2-i], outputs, 1)

            self.waveunets[instrument] = module
        print("set_output_size")
        self.set_output_size(target_output_size)

    def set_output_size(self, target_output_size):
        self.target_output_size = target_output_size

        self.input_size, self.output_size = self.check_padding(target_output_size)
        print("Using valid convolutions with " + str(self.input_size) + " inputs and " + str(self.output_size) + " outputs")

        assert((self.input_size - self.output_size) % 2 == 0)
        self.shapes = {"output_start_frame" : (self.input_size - self.output_size) // 2,
                       "output_end_frame" : (self.input_size - self.output_size) // 2 + self.output_size,
                       "output_frames" : self.output_size,
                       "input_frames" : self.input_size}

    def check_padding(self, target_output_size):
        # Ensure number of outputs covers a whole number of cycles so each output in the cycle is weighted equally during training
        bottleneck = 1

        while True:
            out = self.check_padding_for_bottleneck(bottleneck, target_output_size)
            if out is not False:
                return out
            bottleneck += 1

    def check_padding_for_bottleneck(self, bottleneck, target_output_size):
        module = self.waveunets[[k for k in self.waveunets.keys()][0]]
        try:
            curr_size = bottleneck
            for idx, block in enumerate(module.upsampling_blocks):
                curr_size = block.get_output_size(curr_size)
            output_size = curr_size

            # Bottleneck-Conv
            curr_size = bottleneck
            for block in reversed(module.bottlenecks):
                curr_size = block.get_input_size(curr_size)
            for idx, block in enumerate(reversed(module.downsampling_blocks)):
                curr_size = block.get_input_size(curr_size)
            
            """"""""""""""""""""""""""""""""""""""""""""
#             print("bottleneck,output_size,curr_size,target_output_size",bottleneck,output_size,curr_size,target_output_size)
            assert(output_size >= target_output_size)
            return curr_size, output_size
        except AssertionError as e:
            return False

    def forward_module(self, x, module):
        '''
        A forward pass through a single Wave-U-Net (multiple Wave-U-Nets might be used, one for each source)
        :param x: Input mix
        :param module: Network module to be used for prediction
        :return: Source estimates
        '''
        shortcuts = []
        out = x

        # DOWNSAMPLING BLOCKS
        for block in module.downsampling_blocks:
            out, short = block(out)
            shortcuts.append(short)

        # BOTTLENECK CONVOLUTION
        for conv in module.bottlenecks:
            out = conv(out)

        # UPSAMPLING BLOCKS
        for idx, block in enumerate(module.upsampling_blocks):
            out = block(out, shortcuts[-1 - idx])

        # OUTPUT CONV
        out = module.output_conv(out)
        if not self.training:  # At test time clip predictions to valid amplitude range
            out = out.clamp(min=-1.0, max=1.0)
        return out

    def forward(self, x, inst=None):
        curr_input_size = x.shape[-1]
        assert(curr_input_size == self.input_size) # User promises to feed the proper input himself, to get the pre-calculated (NOT the originally desired) output size

        if self.separate:
            return {inst : self.forward_module(x, self.waveunets[inst])}
        else:
            assert(len(self.waveunets) == 1)
            out = self.forward_module(x, self.waveunets["ALL"])

            out_dict = {}
            for idx, inst in enumerate(self.instruments):
                out_dict[inst] = out[:, idx * self.num_outputs:(idx + 1) * self.num_outputs]
            return out_dict    
    
class Waveunet(nn.Module):
    def __init__(self, num_inputs, num_channels, num_outputs, instruments, kernel_size, target_output_size, conv_type, res, separate=False, depth=1, strides=2):
        super(Waveunet, self).__init__()

        self.num_levels = len(num_channels)
        self.strides = strides
        self.kernel_size = kernel_size
        self.num_inputs = num_inputs
        self.num_outputs = num_outputs
        self.depth = depth
        self.instruments = instruments
        self.separate = separate

        # Only odd filter kernels allowed
        assert(kernel_size % 2 == 1)

        self.waveunets = nn.ModuleDict()

        model_list = instruments if separate else ["ALL"]
        # Create a model for each source if we separate sources separately, otherwise only one (model_list=["ALL"])
        for instrument in model_list:
            module = nn.Module()

            module.downsampling_blocks = nn.ModuleList()
            module.upsampling_blocks = nn.ModuleList()

            for i in range(self.num_levels - 1):
                in_ch = num_inputs if i == 0 else num_channels[i]

                module.downsampling_blocks.append(
                    DownsamplingBlock(in_ch, num_channels[i], num_channels[i+1], kernel_size, strides, depth, conv_type, res))

            for i in range(0, self.num_levels - 1):
                module.upsampling_blocks.append(
                    UpsamplingBlock(num_channels[-1-i], num_channels[-2-i], num_channels[-2-i], kernel_size, strides, depth, conv_type, res))

            module.bottlenecks = nn.ModuleList(
                [ConvLayer(num_channels[-1], num_channels[-1], kernel_size, 1, conv_type) for _ in range(depth)])

            # Output conv
            outputs = num_outputs if separate else num_outputs * len(instruments)
            module.output_conv = nn.Conv1d(num_channels[0], outputs, 1)

            self.waveunets[instrument] = module

        self.set_output_size(target_output_size)

    def set_output_size(self, target_output_size):
        self.target_output_size = target_output_size

        self.input_size, self.output_size = self.check_padding(target_output_size)
        print("Using valid convolutions with " + str(self.input_size) + " inputs and " + str(self.output_size) + " outputs")

        assert((self.input_size - self.output_size) % 2 == 0)
        self.shapes = {"output_start_frame" : (self.input_size - self.output_size) // 2,
                       "output_end_frame" : (self.input_size - self.output_size) // 2 + self.output_size,
                       "output_frames" : self.output_size,
                       "input_frames" : self.input_size}

    def check_padding(self, target_output_size):
        # Ensure number of outputs covers a whole number of cycles so each output in the cycle is weighted equally during training
        bottleneck = 1

        while True:
            out = self.check_padding_for_bottleneck(bottleneck, target_output_size)
            if out is not False:
                return out
            bottleneck += 1

    def check_padding_for_bottleneck(self, bottleneck, target_output_size):
        module = self.waveunets[[k for k in self.waveunets.keys()][0]]
        try:
            curr_size = bottleneck
            for idx, block in enumerate(module.upsampling_blocks):
                curr_size = block.get_output_size(curr_size)
            output_size = curr_size

            # Bottleneck-Conv
            curr_size = bottleneck
            for block in reversed(module.bottlenecks):
                curr_size = block.get_input_size(curr_size)
            for idx, block in enumerate(reversed(module.downsampling_blocks)):
                curr_size = block.get_input_size(curr_size)

            assert(output_size >= target_output_size)
            return curr_size, output_size
        except AssertionError as e:
            return False

    def forward_module(self, x, module):
        '''
        A forward pass through a single Wave-U-Net (multiple Wave-U-Nets might be used, one for each source)
        :param x: Input mix
        :param module: Network module to be used for prediction
        :return: Source estimates
        '''
        shortcuts = []
        out = x

        # DOWNSAMPLING BLOCKS
        for block in module.downsampling_blocks:
            out, short = block(out)
            shortcuts.append(short)

        # BOTTLENECK CONVOLUTION
        for conv in module.bottlenecks:
            out = conv(out)

        # UPSAMPLING BLOCKS
        for idx, block in enumerate(module.upsampling_blocks):
            out = block(out, shortcuts[-1 - idx])

        # OUTPUT CONV
        out = module.output_conv(out)
        if not self.training:  # At test time clip predictions to valid amplitude range
            out = out.clamp(min=-1.0, max=1.0)
        return out

    def forward(self, x, inst=None):
        curr_input_size = x.shape[-1]
        assert(curr_input_size == self.input_size) # User promises to feed the proper input himself, to get the pre-calculated (NOT the originally desired) output size

        if self.separate:
            return {inst : self.forward_module(x, self.waveunets[inst])}
        else:
            assert(len(self.waveunets) == 1)
            out = self.forward_module(x, self.waveunets["ALL"])

            out_dict = {}
            for idx, inst in enumerate(self.instruments):
                out_dict[inst] = out[:, idx * self.num_outputs:(idx + 1) * self.num_outputs]
            return out_dict

# %%
class Parameters:
    def __init__(self):
        self.cuda = True
        self.num_workers = 1
        self.features = 32
        self.log_dir = "./logs/waveunet"
        self.dataset_dir = "/mnt/windaten/Datasets/MUSDB18HQ"
        self.hdf_dir = "hdf"
        self.checkpoint_dir = "checkpoints/waveunet"
#         self.load_model = "waveunet/model"
        self.load_model = None
        self.lr = 1e-3
        self.min_lr = 5e-5
        self.cycles = 2
        self.batch_size = 4
        self.levels = 6
        self.depth = 1
        self.sr = 44100
        self.channels = 2
        self.kernel_size = 5
        self.output_size = 2.0
        self.strides = 4
        self.patience = 20
        self.example_freq = 200
        self.loss = "L1"
        self.conv_type = "gn"
        self.res = "fixed"
        self.separate = 1
        self.feature_growth = "double"
        self.input = "audio_examples/Cristina Vane - So Easy/mix.mp3"
        self.output = "./out"

# %%
# train.py
"""target_outputs = int(args.output_size * args.sr)"""

import argparse
import os
import time

import torch
import pickle
import numpy as np

from torch.utils.tensorboard import SummaryWriter
from torch.optim import Adam
from tqdm import tqdm

import utils
from data import get_musdb_folds, SeparationDataset, random_amplify, crop
# from test import evaluate, validate
# from waveunet import Waveunet

args = Parameters()

INSTRUMENTS = ["bass", "drums", "other", "vocals"]
NUM_INSTRUMENTS = len(INSTRUMENTS)

#torch.backends.cudnn.benchmark=True # This makes dilated conv much faster for CuDNN 7.5

# MODEL
num_features = [args.features*i for i in range(1, args.levels+1)] if args.feature_growth == "add" else \
               [args.features*2**i for i in range(0, args.levels)]
target_outputs = int(args.output_size * args.sr)
# target_outputs = int(256)


model = Waveunet_ctc(args.channels, num_features, args.channels, INSTRUMENTS, kernel_size=args.kernel_size,
                 target_output_size=target_outputs, depth=args.depth, strides=args.strides,
                 conv_type=args.conv_type, res=args.res, separate=args.separate)

if args.cuda:
    model = utils.DataParallel(model)
    print("move model to gpu")
    model.cuda()
    
print('model: ', model)
print('parameter count: ', str(sum(p.numel() for p in model.parameters())))

writer = SummaryWriter(args.log_dir)
# Out:
# bottleneck,output_size,curr_size,target_output_size 4 9 9897 88200
# bottleneck,output_size,curr_size,target_output_size 5 25 10921 88200
# bottleneck,output_size,curr_size,target_output_size 6 41 11945 88200
# bottleneck,output_size,curr_size,target_output_size 7 57 12969 88200
# bottleneck,output_size,curr_size,target_output_size 8 73 13993 88200
# bottleneck,output_size,curr_size,target_output_size 9 89 15017 88200
# bottleneck,output_size,curr_size,target_output_size 10 105 16041 88200
# bottleneck,output_size,curr_size,target_output_size 11 121 17065 88200
# bottleneck,output_size,curr_size,target_output_size 12 137 18089 88200
# bottleneck,output_size,curr_size,target_output_size 13 153 19113 88200
# bottleneck,output_size,curr_size,target_output_size 14 169 20137 88200
# bottleneck,output_size,curr_size,target_output_size 15 185 21161 88200
# bottleneck,output_size,curr_size,target_output_size 16 201 22185 88200
# bottleneck,output_size,curr_size,target_output_size 17 217 23209 88200
# bottleneck,output_size,curr_size,target_output_size 18 233 24233 88200
# bottleneck,output_size,curr_size,target_output_size 19 249 25257 88200
# bottleneck,output_size,curr_size,target_output_size 20 265 26281 88200
# bottleneck,output_size,curr_size,target_output_size 21 281 27305 88200
# bottleneck,output_size,curr_size,target_output_size 22 297 28329 88200
# bottleneck,output_size,curr_size,target_output_size 23 313 29353 88200
# bottleneck,output_size,curr_size,target_output_size 24 329 30377 88200
# bottleneck,output_size,curr_size,target_output_size 25 345 31401 88200
# bottleneck,output_size,curr_size,target_output_size 26 361 32425 88200
# bottleneck,output_size,curr_size,target_output_size 27 377 33449 88200
# bottleneck,output_size,curr_size,target_output_size 28 393 34473 88200
# bottleneck,output_size,curr_size,target_output_size 29 409 35497 88200
# bottleneck,output_size,curr_size,target_output_size 30 425 36521 88200
# bottleneck,output_size,curr_size,target_output_size 31 441 37545 88200
# bottleneck,output_size,curr_size,target_output_size 32 457 38569 88200
# bottleneck,output_size,curr_size,target_output_size 33 473 39593 88200
# bottleneck,output_size,curr_size,target_output_size 34 489 40617 88200
# bottleneck,output_size,curr_size,target_output_size 35 505 41641 88200
# bottleneck,output_size,curr_size,target_output_size 36 521 42665 88200
# bottleneck,output_size,curr_size,target_output_size 37 537 43689 88200
# bottleneck,output_size,curr_size,target_output_size 38 553 44713 88200
# bottleneck,output_size,curr_size,target_output_size 39 569 45737 88200
# bottleneck,output_size,curr_size,target_output_size 40 585 46761 88200
# bottleneck,output_size,curr_size,target_output_size 41 601 47785 88200
# bottleneck,output_size,curr_size,target_output_size 42 617 48809 88200
# bottleneck,output_size,curr_size,target_output_size 43 633 49833 88200
# bottleneck,output_size,curr_size,target_output_size 44 649 50857 88200
# bottleneck,output_size,curr_size,target_output_size 45 665 51881 88200
# bottleneck,output_size,curr_size,target_output_size 46 681 52905 88200
# bottleneck,output_size,curr_size,target_output_size 47 697 53929 88200
# bottleneck,output_size,curr_size,target_output_size 48 713 54953 88200
# bottleneck,output_size,curr_size,target_output_size 49 729 55977 88200
# bottleneck,output_size,curr_size,target_output_size 50 745 57001 88200
# bottleneck,output_size,curr_size,target_output_size 51 761 58025 88200
# bottleneck,output_size,curr_size,target_output_size 52 777 59049 88200
# bottleneck,output_size,curr_size,target_output_size 53 793 60073 88200
# bottleneck,output_size,curr_size,target_output_size 54 809 61097 88200
# bottleneck,output_size,curr_size,target_output_size 55 825 62121 88200
# bottleneck,output_size,curr_size,target_output_size 56 841 63145 88200
# bottleneck,output_size,curr_size,target_output_size 57 857 64169 88200
# bottleneck,output_size,curr_size,target_output_size 58 873 65193 88200
# bottleneck,output_size,curr_size,target_output_size 59 889 66217 88200
# bottleneck,output_size,curr_size,target_output_size 60 905 67241 88200
# bottleneck,output_size,curr_size,target_output_size 61 921 68265 88200
# bottleneck,output_size,curr_size,target_output_size 62 937 69289 88200
# bottleneck,output_size,curr_size,target_output_size 63 953 70313 88200
# bottleneck,output_size,curr_size,target_output_size 64 969 71337 88200
# bottleneck,output_size,curr_size,target_output_size 65 985 72361 88200
# bottleneck,output_size,curr_size,target_output_size 66 1001 73385 88200
# bottleneck,output_size,curr_size,target_output_size 67 1017 74409 88200
# bottleneck,output_size,curr_size,target_output_size 68 1033 75433 88200
# bottleneck,output_size,curr_size,target_output_size 69 1049 76457 88200
# bottleneck,output_size,curr_size,target_output_size 70 1065 77481 88200
# bottleneck,output_size,curr_size,target_output_size 71 1081 78505 88200
# bottleneck,output_size,curr_size,target_output_size 72 1097 79529 88200
# bottleneck,output_size,curr_size,target_output_size 73 1113 80553 88200
# bottleneck,output_size,curr_size,target_output_size 74 1129 81577 88200
# bottleneck,output_size,curr_size,target_output_size 75 1145 82601 88200
# bottleneck,output_size,curr_size,target_output_size 76 1161 83625 88200
# bottleneck,output_size,curr_size,target_output_size 77 1177 84649 88200
# bottleneck,output_size,curr_size,target_output_size 78 1193 85673 88200
# bottleneck,output_size,curr_size,target_output_size 79 1209 86697 88200
# bottleneck,output_size,curr_size,target_output_size 80 1225 87721 88200
# bottleneck,output_size,curr_size,target_output_size 81 1241 88745 88200
# bottleneck,output_size,curr_size,target_output_size 82 1257 89769 88200
# bottleneck,output_size,curr_size,target_output_size 83 1273 90793 88200
# bottleneck,output_size,curr_size,target_output_size 84 1289 91817 88200
# bottleneck,output_size,curr_size,target_output_size 85 1305 92841 88200
# bottleneck,output_size,curr_size,target_output_size 86 1321 93865 88200
# bottleneck,output_size,curr_size,target_output_size 87 1337 94889 88200
# bottleneck,output_size,curr_size,target_output_size 88 1353 95913 88200
# bottleneck,output_size,curr_size,target_output_size 89 1369 96937 88200
# bottleneck,output_size,curr_size,target_output_size 90 1385 97961 88200
# bottleneck,output_size,curr_size,target_output_size 91 1401 98985 88200
# bottleneck,output_size,curr_size,target_output_size 92 1417 100009 88200
# bottleneck,output_size,curr_size,target_output_size 93 1433 101033 88200
# bottleneck,output_size,curr_size,target_output_size 94 1449 102057 88200
# bottleneck,output_size,curr_size,target_output_size 95 1465 103081 88200
# bottleneck,output_size,curr_size,target_output_size 96 1481 104105 88200
# bottleneck,output_size,curr_size,target_output_size 97 1497 105129 88200
# bottleneck,output_size,curr_size,target_output_size 98 1513 106153 88200
# bottleneck,output_size,curr_size,target_output_size 99 1529 107177 88200
# bottleneck,output_size,curr_size,target_output_size 100 1545 108201 88200
# bottleneck,output_size,curr_size,target_output_size 101 1561 109225 88200
# bottleneck,output_size,curr_size,target_output_size 102 1577 110249 88200
# bottleneck,output_size,curr_size,target_output_size 103 1593 111273 88200
# bottleneck,output_size,curr_size,target_output_size 104 1609 112297 88200
# bottleneck,output_size,curr_size,target_output_size 105 1625 113321 88200
# bottleneck,output_size,curr_size,target_output_size 106 1641 114345 88200
# bottleneck,output_size,curr_size,target_output_size 107 1657 115369 88200
# bottleneck,output_size,curr_size,target_output_size 108 1673 116393 88200
# bottleneck,output_size,curr_size,target_output_size 109 1689 117417 88200
# bottleneck,output_size,curr_size,target_output_size 110 1705 118441 88200
# bottleneck,output_size,curr_size,target_output_size 111 1721 119465 88200
# bottleneck,output_size,curr_size,target_output_size 112 1737 120489 88200
# bottleneck,output_size,curr_size,target_output_size 113 1753 121513 88200
# bottleneck,output_size,curr_size,target_output_size 114 1769 122537 88200
# bottleneck,output_size,curr_size,target_output_size 115 1785 123561 88200
# bottleneck,output_size,curr_size,target_output_size 116 1801 124585 88200
# bottleneck,output_size,curr_size,target_output_size 117 1817 125609 88200
# bottleneck,output_size,curr_size,target_output_size 118 1833 126633 88200
# bottleneck,output_size,curr_size,target_output_size 119 1849 127657 88200
# bottleneck,output_size,curr_size,target_output_size 120 1865 128681 88200
# bottleneck,output_size,curr_size,target_output_size 121 1881 129705 88200
# bottleneck,output_size,curr_size,target_output_size 122 1897 130729 88200
# bottleneck,output_size,curr_size,target_output_size 123 1913 131753 88200
# bottleneck,output_size,curr_size,target_output_size 124 1929 132777 88200
# bottleneck,output_size,curr_size,target_output_size 125 1945 133801 88200
# bottleneck,output_size,curr_size,target_output_size 126 1961 134825 88200
# bottleneck,output_size,curr_size,target_output_size 127 1977 135849 88200
# bottleneck,output_size,curr_size,target_output_size 128 1993 136873 88200
# bottleneck,output_size,curr_size,target_output_size 129 2009 137897 88200
# bottleneck,output_size,curr_size,target_output_size 130 2025 138921 88200
# bottleneck,output_size,curr_size,target_output_size 131 2041 139945 88200
# bottleneck,output_size,curr_size,target_output_size 132 2057 140969 88200
# bottleneck,output_size,curr_size,target_output_size 133 2073 141993 88200
# bottleneck,output_size,curr_size,target_output_size 134 2089 143017 88200
# bottleneck,output_size,curr_size,target_output_size 135 2105 144041 88200
# bottleneck,output_size,curr_size,target_output_size 136 2121 145065 88200
# bottleneck,output_size,curr_size,target_output_size 137 2137 146089 88200
# bottleneck,output_size,curr_size,target_output_size 138 2153 147113 88200
# bottleneck,output_size,curr_size,target_output_size 139 2169 148137 88200
# bottleneck,output_size,curr_size,target_output_size 140 2185 149161 88200
# bottleneck,output_size,curr_size,target_output_size 141 2201 150185 88200
# bottleneck,output_size,curr_size,target_output_size 142 2217 151209 88200
# bottleneck,output_size,curr_size,target_output_size 143 2233 152233 88200
# bottleneck,output_size,curr_size,target_output_size 144 2249 153257 88200
# bottleneck,output_size,curr_size,target_output_size 145 2265 154281 88200
# bottleneck,output_size,curr_size,target_output_size 146 2281 155305 88200
# bottleneck,output_size,curr_size,target_output_size 147 2297 156329 88200
# bottleneck,output_size,curr_size,target_output_size 148 2313 157353 88200
# bottleneck,output_size,curr_size,target_output_size 149 2329 158377 88200
# bottleneck,output_size,curr_size,target_output_size 150 2345 159401 88200
# bottleneck,output_size,curr_size,target_output_size 151 2361 160425 88200
# bottleneck,output_size,curr_size,target_output_size 152 2377 161449 88200
# bottleneck,output_size,curr_size,target_output_size 153 2393 162473 88200
# bottleneck,output_size,curr_size,target_output_size 154 2409 163497 88200
# bottleneck,output_size,curr_size,target_output_size 155 2425 164521 88200
# bottleneck,output_size,curr_size,target_output_size 156 2441 165545 88200
# bottleneck,output_size,curr_size,target_output_size 157 2457 166569 88200
# bottleneck,output_size,curr_size,target_output_size 158 2473 167593 88200
# bottleneck,output_size,curr_size,target_output_size 159 2489 168617 88200
# bottleneck,output_size,curr_size,target_output_size 160 2505 169641 88200
# bottleneck,output_size,curr_size,target_output_size 161 2521 170665 88200
# bottleneck,output_size,curr_size,target_output_size 162 2537 171689 88200
# bottleneck,output_size,curr_size,target_output_size 163 2553 172713 88200
# bottleneck,output_size,curr_size,target_output_size 164 2569 173737 88200
# bottleneck,output_size,curr_size,target_output_size 165 2585 174761 88200
# bottleneck,output_size,curr_size,target_output_size 166 2601 175785 88200
# bottleneck,output_size,curr_size,target_output_size 167 2617 176809 88200
# bottleneck,output_size,curr_size,target_output_size 168 2633 177833 88200
# bottleneck,output_size,curr_size,target_output_size 169 2649 178857 88200
# bottleneck,output_size,curr_size,target_output_size 170 2665 179881 88200
# bottleneck,output_size,curr_size,target_output_size 171 2681 180905 88200
# bottleneck,output_size,curr_size,target_output_size 172 2697 181929 88200
# bottleneck,output_size,curr_size,target_output_size 173 2713 182953 88200
# bottleneck,output_size,curr_size,target_output_size 174 2729 183977 88200
# bottleneck,output_size,curr_size,target_output_size 175 2745 185001 88200
# bottleneck,output_size,curr_size,target_output_size 176 2761 186025 88200
# bottleneck,output_size,curr_size,target_output_size 177 2777 187049 88200
# bottleneck,output_size,curr_size,target_output_size 178 2793 188073 88200
# bottleneck,output_size,curr_size,target_output_size 179 2809 189097 88200
# bottleneck,output_size,curr_size,target_output_size 180 2825 190121 88200
# bottleneck,output_size,curr_size,target_output_size 181 2841 191145 88200
# bottleneck,output_size,curr_size,target_output_size 182 2857 192169 88200
# bottleneck,output_size,curr_size,target_output_size 183 2873 193193 88200
# bottleneck,output_size,curr_size,target_output_size 184 2889 194217 88200
# bottleneck,output_size,curr_size,target_output_size 185 2905 195241 88200
# bottleneck,output_size,curr_size,target_output_size 186 2921 196265 88200
# bottleneck,output_size,curr_size,target_output_size 187 2937 197289 88200
# bottleneck,output_size,curr_size,target_output_size 188 2953 198313 88200
# bottleneck,output_size,curr_size,target_output_size 189 2969 199337 88200
# bottleneck,output_size,curr_size,target_output_size 190 2985 200361 88200
# bottleneck,output_size,curr_size,target_output_size 191 3001 201385 88200
# bottleneck,output_size,curr_size,target_output_size 192 3017 202409 88200
# bottleneck,output_size,curr_size,target_output_size 193 3033 203433 88200
# bottleneck,output_size,curr_size,target_output_size 194 3049 204457 88200
# bottleneck,output_size,curr_size,target_output_size 195 3065 205481 88200
# bottleneck,output_size,curr_size,target_output_size 196 3081 206505 88200
# bottleneck,output_size,curr_size,target_output_size 197 3097 207529 88200
# bottleneck,output_size,curr_size,target_output_size 198 3113 208553 88200
# bottleneck,output_size,curr_size,target_output_size 199 3129 209577 88200
# bottleneck,output_size,curr_size,target_output_size 200 3145 210601 88200
# bottleneck,output_size,curr_size,target_output_size 201 3161 211625 88200
# bottleneck,output_size,curr_size,target_output_size 202 3177 212649 88200
# bottleneck,output_size,curr_size,target_output_size 203 3193 213673 88200
# bottleneck,output_size,curr_size,target_output_size 204 3209 214697 88200
# bottleneck,output_size,curr_size,target_output_size 205 3225 215721 88200
# bottleneck,output_size,curr_size,target_output_size 206 3241 216745 88200
# bottleneck,output_size,curr_size,target_output_size 207 3257 217769 88200
# bottleneck,output_size,curr_size,target_output_size 208 3273 218793 88200
# bottleneck,output_size,curr_size,target_output_size 209 3289 219817 88200
# bottleneck,output_size,curr_size,target_output_size 210 3305 220841 88200
# bottleneck,output_size,curr_size,target_output_size 211 3321 221865 88200
# bottleneck,output_size,curr_size,target_output_size 212 3337 222889 88200
# bottleneck,output_size,curr_size,target_output_size 213 3353 223913 88200
# bottleneck,output_size,curr_size,target_output_size 214 3369 224937 88200
# bottleneck,output_size,curr_size,target_output_size 215 3385 225961 88200
# bottleneck,output_size,curr_size,target_output_size 216 3401 226985 88200
# bottleneck,output_size,curr_size,target_output_size 217 3417 228009 88200
# bottleneck,output_size,curr_size,target_output_size 218 3433 229033 88200
# bottleneck,output_size,curr_size,target_output_size 219 3449 230057 88200
# bottleneck,output_size,curr_size,target_output_size 220 3465 231081 88200
# bottleneck,output_size,curr_size,target_output_size 221 3481 232105 88200
# bottleneck,output_size,curr_size,target_output_size 222 3497 233129 88200
# bottleneck,output_size,curr_size,target_output_size 223 3513 234153 88200
# bottleneck,output_size,curr_size,target_output_size 224 3529 235177 88200
# bottleneck,output_size,curr_size,target_output_size 225 3545 236201 88200
# bottleneck,output_size,curr_size,target_output_size 226 3561 237225 88200
# bottleneck,output_size,curr_size,target_output_size 227 3577 238249 88200
# bottleneck,output_size,curr_size,target_output_size 228 3593 239273 88200
# bottleneck,output_size,curr_size,target_output_size 229 3609 240297 88200
# bottleneck,output_size,curr_size,target_output_size 230 3625 241321 88200
# bottleneck,output_size,curr_size,target_output_size 231 3641 242345 88200
# bottleneck,output_size,curr_size,target_output_size 232 3657 243369 88200
# bottleneck,output_size,curr_size,target_output_size 233 3673 244393 88200
# bottleneck,output_size,curr_size,target_output_size 234 3689 245417 88200
# bottleneck,output_size,curr_size,target_output_size 235 3705 246441 88200
# bottleneck,output_size,curr_size,target_output_size 236 3721 247465 88200
# bottleneck,output_size,curr_size,target_output_size 237 3737 248489 88200
# bottleneck,output_size,curr_size,target_output_size 238 3753 249513 88200
# bottleneck,output_size,curr_size,target_output_size 239 3769 250537 88200
# bottleneck,output_size,curr_size,target_output_size 240 3785 251561 88200
# bottleneck,output_size,curr_size,target_output_size 241 3801 252585 88200
# bottleneck,output_size,curr_size,target_output_size 242 3817 253609 88200
# bottleneck,output_size,curr_size,target_output_size 243 3833 254633 88200
# bottleneck,output_size,curr_size,target_output_size 244 3849 255657 88200
# bottleneck,output_size,curr_size,target_output_size 245 3865 256681 88200
# bottleneck,output_size,curr_size,target_output_size 246 3881 257705 88200
# bottleneck,output_size,curr_size,target_output_size 247 3897 258729 88200
# bottleneck,output_size,curr_size,target_output_size 248 3913 259753 88200
# bottleneck,output_size,curr_size,target_output_size 249 3929 260777 88200
# bottleneck,output_size,curr_size,target_output_size 250 3945 261801 88200
# bottleneck,output_size,curr_size,target_output_size 251 3961 262825 88200
# bottleneck,output_size,curr_size,target_output_size 252 3977 263849 88200
# bottleneck,output_size,curr_size,target_output_size 253 3993 264873 88200
# bottleneck,output_size,curr_size,target_output_size 254 4009 265897 88200
# bottleneck,output_size,curr_size,target_output_size 255 4025 266921 88200
# bottleneck,output_size,curr_size,target_output_size 256 4041 267945 88200
# bottleneck,output_size,curr_size,target_output_size 257 4057 268969 88200
# bottleneck,output_size,curr_size,target_output_size 258 4073 269993 88200
# bottleneck,output_size,curr_size,target_output_size 259 4089 271017 88200
# bottleneck,output_size,curr_size,target_output_size 260 4105 272041 88200
# bottleneck,output_size,curr_size,target_output_size 261 4121 273065 88200
# bottleneck,output_size,curr_size,target_output_size 262 4137 274089 88200
# bottleneck,output_size,curr_size,target_output_size 263 4153 275113 88200
# bottleneck,output_size,curr_size,target_output_size 264 4169 276137 88200
# bottleneck,output_size,curr_size,target_output_size 265 4185 277161 88200
# bottleneck,output_size,curr_size,target_output_size 266 4201 278185 88200
# bottleneck,output_size,curr_size,target_output_size 267 4217 279209 88200
# bottleneck,output_size,curr_size,target_output_size 268 4233 280233 88200
# bottleneck,output_size,curr_size,target_output_size 269 4249 281257 88200
# bottleneck,output_size,curr_size,target_output_size 270 4265 282281 88200
# bottleneck,output_size,curr_size,target_output_size 271 4281 283305 88200
# bottleneck,output_size,curr_size,target_output_size 272 4297 284329 88200
# bottleneck,output_size,curr_size,target_output_size 273 4313 285353 88200
# bottleneck,output_size,curr_size,target_output_size 274 4329 286377 88200
# bottleneck,output_size,curr_size,target_output_size 275 4345 287401 88200
# bottleneck,output_size,curr_size,target_output_size 276 4361 288425 88200
# bottleneck,output_size,curr_size,target_output_size 277 4377 289449 88200
# bottleneck,output_size,curr_size,target_output_size 278 4393 290473 88200
# bottleneck,output_size,curr_size,target_output_size 279 4409 291497 88200
# bottleneck,output_size,curr_size,target_output_size 280 4425 292521 88200
# bottleneck,output_size,curr_size,target_output_size 281 4441 293545 88200
# bottleneck,output_size,curr_size,target_output_size 282 4457 294569 88200
# bottleneck,output_size,curr_size,target_output_size 283 4473 295593 88200
# bottleneck,output_size,curr_size,target_output_size 284 4489 296617 88200
# bottleneck,output_size,curr_size,target_output_size 285 4505 297641 88200
# bottleneck,output_size,curr_size,target_output_size 286 4521 298665 88200
# bottleneck,output_size,curr_size,target_output_size 287 4537 299689 88200
# bottleneck,output_size,curr_size,target_output_size 288 4553 300713 88200
# bottleneck,output_size,curr_size,target_output_size 289 4569 301737 88200
# bottleneck,output_size,curr_size,target_output_size 290 4585 302761 88200
# bottleneck,output_size,curr_size,target_output_size 291 4601 303785 88200
# bottleneck,output_size,curr_size,target_output_size 292 4617 304809 88200
# bottleneck,output_size,curr_size,target_output_size 293 4633 305833 88200
# bottleneck,output_size,curr_size,target_output_size 294 4649 306857 88200
# bottleneck,output_size,curr_size,target_output_size 295 4665 307881 88200
# bottleneck,output_size,curr_size,target_output_size 296 4681 308905 88200
# bottleneck,output_size,curr_size,target_output_size 297 4697 309929 88200
# bottleneck,output_size,curr_size,target_output_size 298 4713 310953 88200
# bottleneck,output_size,curr_size,target_output_size 299 4729 311977 88200
# bottleneck,output_size,curr_size,target_output_size 300 4745 313001 88200
# bottleneck,output_size,curr_size,target_output_size 301 4761 314025 88200
# bottleneck,output_size,curr_size,target_output_size 302 4777 315049 88200
# bottleneck,output_size,curr_size,target_output_size 303 4793 316073 88200
# bottleneck,output_size,curr_size,target_output_size 304 4809 317097 88200
# bottleneck,output_size,curr_size,target_output_size 305 4825 318121 88200
# bottleneck,output_size,curr_size,target_output_size 306 4841 319145 88200
# bottleneck,output_size,curr_size,target_output_size 307 4857 320169 88200
# bottleneck,output_size,curr_size,target_output_size 308 4873 321193 88200
# bottleneck,output_size,curr_size,target_output_size 309 4889 322217 88200
# bottleneck,output_size,curr_size,target_output_size 310 4905 323241 88200
# bottleneck,output_size,curr_size,target_output_size 311 4921 324265 88200
# bottleneck,output_size,curr_size,target_output_size 312 4937 325289 88200
# bottleneck,output_size,curr_size,target_output_size 313 4953 326313 88200
# bottleneck,output_size,curr_size,target_output_size 314 4969 327337 88200
# bottleneck,output_size,curr_size,target_output_size 315 4985 328361 88200
# bottleneck,output_size,curr_size,target_output_size 316 5001 329385 88200
# bottleneck,output_size,curr_size,target_output_size 317 5017 330409 88200
# bottleneck,output_size,curr_size,target_output_size 318 5033 331433 88200
# bottleneck,output_size,curr_size,target_output_size 319 5049 332457 88200
# bottleneck,output_size,curr_size,target_output_size 320 5065 333481 88200
# bottleneck,output_size,curr_size,target_output_size 321 5081 334505 88200
# bottleneck,output_size,curr_size,target_output_size 322 5097 335529 88200
# bottleneck,output_size,curr_size,target_output_size 323 5113 336553 88200
# bottleneck,output_size,curr_size,target_output_size 324 5129 337577 88200
# bottleneck,output_size,curr_size,target_output_size 325 5145 338601 88200
# bottleneck,output_size,curr_size,target_output_size 326 5161 339625 88200
# bottleneck,output_size,curr_size,target_output_size 327 5177 340649 88200
# bottleneck,output_size,curr_size,target_output_size 328 5193 341673 88200
# bottleneck,output_size,curr_size,target_output_size 329 5209 342697 88200
# bottleneck,output_size,curr_size,target_output_size 330 5225 343721 88200
# bottleneck,output_size,curr_size,target_output_size 331 5241 344745 88200
# bottleneck,output_size,curr_size,target_output_size 332 5257 345769 88200
# bottleneck,output_size,curr_size,target_output_size 333 5273 346793 88200
# bottleneck,output_size,curr_size,target_output_size 334 5289 347817 88200
# bottleneck,output_size,curr_size,target_output_size 335 5305 348841 88200
# bottleneck,output_size,curr_size,target_output_size 336 5321 349865 88200
# bottleneck,output_size,curr_size,target_output_size 337 5337 350889 88200
# bottleneck,output_size,curr_size,target_output_size 338 5353 351913 88200
# bottleneck,output_size,curr_size,target_output_size 339 5369 352937 88200
# bottleneck,output_size,curr_size,target_output_size 340 5385 353961 88200
# bottleneck,output_size,curr_size,target_output_size 341 5401 354985 88200
# bottleneck,output_size,curr_size,target_output_size 342 5417 356009 88200
# bottleneck,output_size,curr_size,target_output_size 343 5433 357033 88200
# bottleneck,output_size,curr_size,target_output_size 344 5449 358057 88200
# bottleneck,output_size,curr_size,target_output_size 345 5465 359081 88200
# bottleneck,output_size,curr_size,target_output_size 346 5481 360105 88200
# bottleneck,output_size,curr_size,target_output_size 347 5497 361129 88200
# bottleneck,output_size,curr_size,target_output_size 348 5513 362153 88200
# bottleneck,output_size,curr_size,target_output_size 349 5529 363177 88200
# bottleneck,output_size,curr_size,target_output_size 350 5545 364201 88200
# bottleneck,output_size,curr_size,target_output_size 351 5561 365225 88200
# bottleneck,output_size,curr_size,target_output_size 352 5577 366249 88200
# bottleneck,output_size,curr_size,target_output_size 353 5593 367273 88200
# bottleneck,output_size,curr_size,target_output_size 354 5609 368297 88200
# bottleneck,output_size,curr_size,target_output_size 355 5625 369321 88200
# bottleneck,output_size,curr_size,target_output_size 356 5641 370345 88200
# bottleneck,output_size,curr_size,target_output_size 357 5657 371369 88200
# bottleneck,output_size,curr_size,target_output_size 358 5673 372393 88200
# bottleneck,output_size,curr_size,target_output_size 359 5689 373417 88200
# bottleneck,output_size,curr_size,target_output_size 360 5705 374441 88200
# bottleneck,output_size,curr_size,target_output_size 361 5721 375465 88200
# bottleneck,output_size,curr_size,target_output_size 362 5737 376489 88200
# bottleneck,output_size,curr_size,target_output_size 363 5753 377513 88200
# bottleneck,output_size,curr_size,target_output_size 364 5769 378537 88200
# bottleneck,output_size,curr_size,target_output_size 365 5785 379561 88200
# bottleneck,output_size,curr_size,target_output_size 366 5801 380585 88200
# bottleneck,output_size,curr_size,target_output_size 367 5817 381609 88200
# bottleneck,output_size,curr_size,target_output_size 368 5833 382633 88200
# bottleneck,output_size,curr_size,target_output_size 369 5849 383657 88200
# bottleneck,output_size,curr_size,target_output_size 370 5865 384681 88200
# bottleneck,output_size,curr_size,target_output_size 371 5881 385705 88200
# bottleneck,output_size,curr_size,target_output_size 372 5897 386729 88200
# bottleneck,output_size,curr_size,target_output_size 373 5913 387753 88200
# bottleneck,output_size,curr_size,target_output_size 374 5929 388777 88200
# bottleneck,output_size,curr_size,target_output_size 375 5945 389801 88200
# bottleneck,output_size,curr_size,target_output_size 376 5961 390825 88200
# bottleneck,output_size,curr_size,target_output_size 377 5977 391849 88200
# bottleneck,output_size,curr_size,target_output_size 378 5993 392873 88200
# bottleneck,output_size,curr_size,target_output_size 379 6009 393897 88200
# bottleneck,output_size,curr_size,target_output_size 380 6025 394921 88200
# bottleneck,output_size,curr_size,target_output_size 381 6041 395945 88200
# bottleneck,output_size,curr_size,target_output_size 382 6057 396969 88200
# bottleneck,output_size,curr_size,target_output_size 383 6073 397993 88200
# bottleneck,output_size,curr_size,target_output_size 384 6089 399017 88200
# bottleneck,output_size,curr_size,target_output_size 385 6105 400041 88200
# bottleneck,output_size,curr_size,target_output_size 386 6121 401065 88200
# bottleneck,output_size,curr_size,target_output_size 387 6137 402089 88200
# bottleneck,output_size,curr_size,target_output_size 388 6153 403113 88200
# bottleneck,output_size,curr_size,target_output_size 389 6169 404137 88200
# bottleneck,output_size,curr_size,target_output_size 390 6185 405161 88200
# bottleneck,output_size,curr_size,target_output_size 391 6201 406185 88200
# bottleneck,output_size,curr_size,target_output_size 392 6217 407209 88200
# bottleneck,output_size,curr_size,target_output_size 393 6233 408233 88200
# bottleneck,output_size,curr_size,target_output_size 394 6249 409257 88200
# bottleneck,output_size,curr_size,target_output_size 395 6265 410281 88200
# bottleneck,output_size,curr_size,target_output_size 396 6281 411305 88200
# bottleneck,output_size,curr_size,target_output_size 397 6297 412329 88200
# bottleneck,output_size,curr_size,target_output_size 398 6313 413353 88200
# bottleneck,output_size,curr_size,target_output_size 399 6329 414377 88200
# bottleneck,output_size,curr_size,target_output_size 400 6345 415401 88200
# bottleneck,output_size,curr_size,target_output_size 401 6361 416425 88200
# bottleneck,output_size,curr_size,target_output_size 402 6377 417449 88200
# bottleneck,output_size,curr_size,target_output_size 403 6393 418473 88200
# bottleneck,output_size,curr_size,target_output_size 404 6409 419497 88200
# bottleneck,output_size,curr_size,target_output_size 405 6425 420521 88200
# bottleneck,output_size,curr_size,target_output_size 406 6441 421545 88200
# bottleneck,output_size,curr_size,target_output_size 407 6457 422569 88200
# bottleneck,output_size,curr_size,target_output_size 408 6473 423593 88200
# bottleneck,output_size,curr_size,target_output_size 409 6489 424617 88200
# bottleneck,output_size,curr_size,target_output_size 410 6505 425641 88200
# bottleneck,output_size,curr_size,target_output_size 411 6521 426665 88200
# bottleneck,output_size,curr_size,target_output_size 412 6537 427689 88200
# bottleneck,output_size,curr_size,target_output_size 413 6553 428713 88200
# bottleneck,output_size,curr_size,target_output_size 414 6569 429737 88200
# bottleneck,output_size,curr_size,target_output_size 415 6585 430761 88200
# bottleneck,output_size,curr_size,target_output_size 416 6601 431785 88200
# bottleneck,output_size,curr_size,target_output_size 417 6617 432809 88200
# bottleneck,output_size,curr_size,target_output_size 418 6633 433833 88200
# bottleneck,output_size,curr_size,target_output_size 419 6649 434857 88200
# bottleneck,output_size,curr_size,target_output_size 420 6665 435881 88200
# bottleneck,output_size,curr_size,target_output_size 421 6681 436905 88200
# bottleneck,output_size,curr_size,target_output_size 422 6697 437929 88200
# bottleneck,output_size,curr_size,target_output_size 423 6713 438953 88200
# bottleneck,output_size,curr_size,target_output_size 424 6729 439977 88200
# bottleneck,output_size,curr_size,target_output_size 425 6745 441001 88200
# bottleneck,output_size,curr_size,target_output_size 426 6761 442025 88200
# bottleneck,output_size,curr_size,target_output_size 427 6777 443049 88200
# bottleneck,output_size,curr_size,target_output_size 428 6793 444073 88200
# bottleneck,output_size,curr_size,target_output_size 429 6809 445097 88200
# bottleneck,output_size,curr_size,target_output_size 430 6825 446121 88200
# bottleneck,output_size,curr_size,target_output_size 431 6841 447145 88200
# bottleneck,output_size,curr_size,target_output_size 432 6857 448169 88200
# bottleneck,output_size,curr_size,target_output_size 433 6873 449193 88200
# bottleneck,output_size,curr_size,target_output_size 434 6889 450217 88200
# bottleneck,output_size,curr_size,target_output_size 435 6905 451241 88200
# bottleneck,output_size,curr_size,target_output_size 436 6921 452265 88200
# bottleneck,output_size,curr_size,target_output_size 437 6937 453289 88200
# bottleneck,output_size,curr_size,target_output_size 438 6953 454313 88200
# bottleneck,output_size,curr_size,target_output_size 439 6969 455337 88200
# bottleneck,output_size,curr_size,target_output_size 440 6985 456361 88200
# bottleneck,output_size,curr_size,target_output_size 441 7001 457385 88200
# bottleneck,output_size,curr_size,target_output_size 442 7017 458409 88200
# bottleneck,output_size,curr_size,target_output_size 443 7033 459433 88200
# bottleneck,output_size,curr_size,target_output_size 444 7049 460457 88200
# bottleneck,output_size,curr_size,target_output_size 445 7065 461481 88200
# bottleneck,output_size,curr_size,target_output_size 446 7081 462505 88200
# bottleneck,output_size,curr_size,target_output_size 447 7097 463529 88200
# bottleneck,output_size,curr_size,target_output_size 448 7113 464553 88200
# bottleneck,output_size,curr_size,target_output_size 449 7129 465577 88200
# bottleneck,output_size,curr_size,target_output_size 450 7145 466601 88200
# bottleneck,output_size,curr_size,target_output_size 451 7161 467625 88200
# bottleneck,output_size,curr_size,target_output_size 452 7177 468649 88200
# bottleneck,output_size,curr_size,target_output_size 453 7193 469673 88200
# bottleneck,output_size,curr_size,target_output_size 454 7209 470697 88200
# bottleneck,output_size,curr_size,target_output_size 455 7225 471721 88200
# bottleneck,output_size,curr_size,target_output_size 456 7241 472745 88200
# bottleneck,output_size,curr_size,target_output_size 457 7257 473769 88200
# bottleneck,output_size,curr_size,target_output_size 458 7273 474793 88200
# bottleneck,output_size,curr_size,target_output_size 459 7289 475817 88200
# bottleneck,output_size,curr_size,target_output_size 460 7305 476841 88200
# bottleneck,output_size,curr_size,target_output_size 461 7321 477865 88200
# bottleneck,output_size,curr_size,target_output_size 462 7337 478889 88200
# bottleneck,output_size,curr_size,target_output_size 463 7353 479913 88200
# bottleneck,output_size,curr_size,target_output_size 464 7369 480937 88200
# bottleneck,output_size,curr_size,target_output_size 465 7385 481961 88200
# bottleneck,output_size,curr_size,target_output_size 466 7401 482985 88200
# bottleneck,output_size,curr_size,target_output_size 467 7417 484009 88200
# bottleneck,output_size,curr_size,target_output_size 468 7433 485033 88200
# bottleneck,output_size,curr_size,target_output_size 469 7449 486057 88200
# bottleneck,output_size,curr_size,target_output_size 470 7465 487081 88200
# bottleneck,output_size,curr_size,target_output_size 471 7481 488105 88200
# bottleneck,output_size,curr_size,target_output_size 472 7497 489129 88200
# bottleneck,output_size,curr_size,target_output_size 473 7513 490153 88200
# bottleneck,output_size,curr_size,target_output_size 474 7529 491177 88200
# bottleneck,output_size,curr_size,target_output_size 475 7545 492201 88200
# bottleneck,output_size,curr_size,target_output_size 476 7561 493225 88200
# bottleneck,output_size,curr_size,target_output_size 477 7577 494249 88200
# bottleneck,output_size,curr_size,target_output_size 478 7593 495273 88200
# bottleneck,output_size,curr_size,target_output_size 479 7609 496297 88200
# bottleneck,output_size,curr_size,target_output_size 480 7625 497321 88200
# bottleneck,output_size,curr_size,target_output_size 481 7641 498345 88200
# bottleneck,output_size,curr_size,target_output_size 482 7657 499369 88200
# bottleneck,output_size,curr_size,target_output_size 483 7673 500393 88200
# bottleneck,output_size,curr_size,target_output_size 484 7689 501417 88200
# bottleneck,output_size,curr_size,target_output_size 485 7705 502441 88200
# bottleneck,output_size,curr_size,target_output_size 486 7721 503465 88200
# bottleneck,output_size,curr_size,target_output_size 487 7737 504489 88200
# bottleneck,output_size,curr_size,target_output_size 488 7753 505513 88200
# bottleneck,output_size,curr_size,target_output_size 489 7769 506537 88200
# bottleneck,output_size,curr_size,target_output_size 490 7785 507561 88200
# bottleneck,output_size,curr_size,target_output_size 491 7801 508585 88200
# bottleneck,output_size,curr_size,target_output_size 492 7817 509609 88200
# bottleneck,output_size,curr_size,target_output_size 493 7833 510633 88200
# bottleneck,output_size,curr_size,target_output_size 494 7849 511657 88200
# bottleneck,output_size,curr_size,target_output_size 495 7865 512681 88200
# bottleneck,output_size,curr_size,target_output_size 496 7881 513705 88200
# bottleneck,output_size,curr_size,target_output_size 497 7897 514729 88200
# bottleneck,output_size,curr_size,target_output_size 498 7913 515753 88200
# bottleneck,output_size,curr_size,target_output_size 499 7929 516777 88200
# bottleneck,output_size,curr_size,target_output_size 500 7945 517801 88200
# bottleneck,output_size,curr_size,target_output_size 501 7961 518825 88200
# bottleneck,output_size,curr_size,target_output_size 502 7977 519849 88200
# bottleneck,output_size,curr_size,target_output_size 503 7993 520873 88200
# bottleneck,output_size,curr_size,target_output_size 504 8009 521897 88200
# bottleneck,output_size,curr_size,target_output_size 505 8025 522921 88200
# bottleneck,output_size,curr_size,target_output_size 506 8041 523945 88200
# bottleneck,output_size,curr_size,target_output_size 507 8057 524969 88200
# bottleneck,output_size,curr_size,target_output_size 508 8073 525993 88200
# bottleneck,output_size,curr_size,target_output_size 509 8089 527017 88200
# bottleneck,output_size,curr_size,target_output_size 510 8105 528041 88200
# bottleneck,output_size,curr_size,target_output_size 511 8121 529065 88200
# bottleneck,output_size,curr_size,target_output_size 512 8137 530089 88200
# bottleneck,output_size,curr_size,target_output_size 513 8153 531113 88200
# bottleneck,output_size,curr_size,target_output_size 514 8169 532137 88200
# bottleneck,output_size,curr_size,target_output_size 515 8185 533161 88200
# bottleneck,output_size,curr_size,target_output_size 516 8201 534185 88200
# bottleneck,output_size,curr_size,target_output_size 517 8217 535209 88200
# bottleneck,output_size,curr_size,target_output_size 518 8233 536233 88200
# bottleneck,output_size,curr_size,target_output_size 519 8249 537257 88200
# bottleneck,output_size,curr_size,target_output_size 520 8265 538281 88200
# bottleneck,output_size,curr_size,target_output_size 521 8281 539305 88200
# bottleneck,output_size,curr_size,target_output_size 522 8297 540329 88200
# bottleneck,output_size,curr_size,target_output_size 523 8313 541353 88200
# bottleneck,output_size,curr_size,target_output_size 524 8329 542377 88200
# bottleneck,output_size,curr_size,target_output_size 525 8345 543401 88200
# bottleneck,output_size,curr_size,target_output_size 526 8361 544425 88200
# bottleneck,output_size,curr_size,target_output_size 527 8377 545449 88200
# bottleneck,output_size,curr_size,target_output_size 528 8393 546473 88200
# bottleneck,output_size,curr_size,target_output_size 529 8409 547497 88200
# bottleneck,output_size,curr_size,target_output_size 530 8425 548521 88200
# bottleneck,output_size,curr_size,target_output_size 531 8441 549545 88200
# bottleneck,output_size,curr_size,target_output_size 532 8457 550569 88200
# bottleneck,output_size,curr_size,target_output_size 533 8473 551593 88200
# bottleneck,output_size,curr_size,target_output_size 534 8489 552617 88200
# bottleneck,output_size,curr_size,target_output_size 535 8505 553641 88200
# bottleneck,output_size,curr_size,target_output_size 536 8521 554665 88200
# bottleneck,output_size,curr_size,target_output_size 537 8537 555689 88200
# bottleneck,output_size,curr_size,target_output_size 538 8553 556713 88200
# bottleneck,output_size,curr_size,target_output_size 539 8569 557737 88200
# bottleneck,output_size,curr_size,target_output_size 540 8585 558761 88200
# bottleneck,output_size,curr_size,target_output_size 541 8601 559785 88200
# bottleneck,output_size,curr_size,target_output_size 542 8617 560809 88200
# bottleneck,output_size,curr_size,target_output_size 543 8633 561833 88200
# bottleneck,output_size,curr_size,target_output_size 544 8649 562857 88200
# bottleneck,output_size,curr_size,target_output_size 545 8665 563881 88200
# bottleneck,output_size,curr_size,target_output_size 546 8681 564905 88200
# bottleneck,output_size,curr_size,target_output_size 547 8697 565929 88200
# bottleneck,output_size,curr_size,target_output_size 548 8713 566953 88200
# bottleneck,output_size,curr_size,target_output_size 549 8729 567977 88200
# bottleneck,output_size,curr_size,target_output_size 550 8745 569001 88200
# bottleneck,output_size,curr_size,target_output_size 551 8761 570025 88200
# bottleneck,output_size,curr_size,target_output_size 552 8777 571049 88200
# bottleneck,output_size,curr_size,target_output_size 553 8793 572073 88200
# bottleneck,output_size,curr_size,target_output_size 554 8809 573097 88200
# bottleneck,output_size,curr_size,target_output_size 555 8825 574121 88200
# bottleneck,output_size,curr_size,target_output_size 556 8841 575145 88200
# bottleneck,output_size,curr_size,target_output_size 557 8857 576169 88200
# bottleneck,output_size,curr_size,target_output_size 558 8873 577193 88200
# bottleneck,output_size,curr_size,target_output_size 559 8889 578217 88200
# bottleneck,output_size,curr_size,target_output_size 560 8905 579241 88200
# bottleneck,output_size,curr_size,target_output_size 561 8921 580265 88200
# bottleneck,output_size,curr_size,target_output_size 562 8937 581289 88200
# bottleneck,output_size,curr_size,target_output_size 563 8953 582313 88200
# bottleneck,output_size,curr_size,target_output_size 564 8969 583337 88200
# bottleneck,output_size,curr_size,target_output_size 565 8985 584361 88200
# bottleneck,output_size,curr_size,target_output_size 566 9001 585385 88200
# bottleneck,output_size,curr_size,target_output_size 567 9017 586409 88200
# bottleneck,output_size,curr_size,target_output_size 568 9033 587433 88200
# bottleneck,output_size,curr_size,target_output_size 569 9049 588457 88200
# bottleneck,output_size,curr_size,target_output_size 570 9065 589481 88200
# bottleneck,output_size,curr_size,target_output_size 571 9081 590505 88200
# bottleneck,output_size,curr_size,target_output_size 572 9097 591529 88200
# bottleneck,output_size,curr_size,target_output_size 573 9113 592553 88200
# bottleneck,output_size,curr_size,target_output_size 574 9129 593577 88200
# bottleneck,output_size,curr_size,target_output_size 575 9145 594601 88200
# bottleneck,output_size,curr_size,target_output_size 576 9161 595625 88200
# bottleneck,output_size,curr_size,target_output_size 577 9177 596649 88200
# bottleneck,output_size,curr_size,target_output_size 578 9193 597673 88200
# bottleneck,output_size,curr_size,target_output_size 579 9209 598697 88200
# bottleneck,output_size,curr_size,target_output_size 580 9225 599721 88200
# bottleneck,output_size,curr_size,target_output_size 581 9241 600745 88200
# bottleneck,output_size,curr_size,target_output_size 582 9257 601769 88200
# bottleneck,output_size,curr_size,target_output_size 583 9273 602793 88200
# bottleneck,output_size,curr_size,target_output_size 584 9289 603817 88200
# bottleneck,output_size,curr_size,target_output_size 585 9305 604841 88200
# bottleneck,output_size,curr_size,target_output_size 586 9321 605865 88200
# bottleneck,output_size,curr_size,target_output_size 587 9337 606889 88200
# bottleneck,output_size,curr_size,target_output_size 588 9353 607913 88200
# bottleneck,output_size,curr_size,target_output_size 589 9369 608937 88200
# bottleneck,output_size,curr_size,target_output_size 590 9385 609961 88200
# bottleneck,output_size,curr_size,target_output_size 591 9401 610985 88200
# bottleneck,output_size,curr_size,target_output_size 592 9417 612009 88200
# bottleneck,output_size,curr_size,target_output_size 593 9433 613033 88200
# bottleneck,output_size,curr_size,target_output_size 594 9449 614057 88200
# bottleneck,output_size,curr_size,target_output_size 595 9465 615081 88200
# bottleneck,output_size,curr_size,target_output_size 596 9481 616105 88200
# bottleneck,output_size,curr_size,target_output_size 597 9497 617129 88200
# bottleneck,output_size,curr_size,target_output_size 598 9513 618153 88200
# bottleneck,output_size,curr_size,target_output_size 599 9529 619177 88200
# bottleneck,output_size,curr_size,target_output_size 600 9545 620201 88200
# bottleneck,output_size,curr_size,target_output_size 601 9561 621225 88200
# bottleneck,output_size,curr_size,target_output_size 602 9577 622249 88200
# bottleneck,output_size,curr_size,target_output_size 603 9593 623273 88200
# bottleneck,output_size,curr_size,target_output_size 604 9609 624297 88200
# bottleneck,output_size,curr_size,target_output_size 605 9625 625321 88200
# bottleneck,output_size,curr_size,target_output_size 606 9641 626345 88200
# bottleneck,output_size,curr_size,target_output_size 607 9657 627369 88200
# bottleneck,output_size,curr_size,target_output_size 608 9673 628393 88200
# bottleneck,output_size,curr_size,target_output_size 609 9689 629417 88200
# bottleneck,output_size,curr_size,target_output_size 610 9705 630441 88200
# bottleneck,output_size,curr_size,target_output_size 611 9721 631465 88200
# bottleneck,output_size,curr_size,target_output_size 612 9737 632489 88200
# bottleneck,output_size,curr_size,target_output_size 613 9753 633513 88200
# bottleneck,output_size,curr_size,target_output_size 614 9769 634537 88200
# bottleneck,output_size,curr_size,target_output_size 615 9785 635561 88200
# bottleneck,output_size,curr_size,target_output_size 616 9801 636585 88200
# bottleneck,output_size,curr_size,target_output_size 617 9817 637609 88200
# bottleneck,output_size,curr_size,target_output_size 618 9833 638633 88200
# bottleneck,output_size,curr_size,target_output_size 619 9849 639657 88200
# bottleneck,output_size,curr_size,target_output_size 620 9865 640681 88200
# bottleneck,output_size,curr_size,target_output_size 621 9881 641705 88200
# bottleneck,output_size,curr_size,target_output_size 622 9897 642729 88200
# bottleneck,output_size,curr_size,target_output_size 623 9913 643753 88200
# bottleneck,output_size,curr_size,target_output_size 624 9929 644777 88200
# bottleneck,output_size,curr_size,target_output_size 625 9945 645801 88200
# bottleneck,output_size,curr_size,target_output_size 626 9961 646825 88200
# bottleneck,output_size,curr_size,target_output_size 627 9977 647849 88200
# bottleneck,output_size,curr_size,target_output_size 628 9993 648873 88200
# bottleneck,output_size,curr_size,target_output_size 629 10009 649897 88200
# bottleneck,output_size,curr_size,target_output_size 630 10025 650921 88200
# bottleneck,output_size,curr_size,target_output_size 631 10041 651945 88200
# bottleneck,output_size,curr_size,target_output_size 632 10057 652969 88200
# bottleneck,output_size,curr_size,target_output_size 633 10073 653993 88200
# bottleneck,output_size,curr_size,target_output_size 634 10089 655017 88200
# bottleneck,output_size,curr_size,target_output_size 635 10105 656041 88200
# bottleneck,output_size,curr_size,target_output_size 636 10121 657065 88200
# bottleneck,output_size,curr_size,target_output_size 637 10137 658089 88200
# bottleneck,output_size,curr_size,target_output_size 638 10153 659113 88200
# bottleneck,output_size,curr_size,target_output_size 639 10169 660137 88200
# bottleneck,output_size,curr_size,target_output_size 640 10185 661161 88200
# bottleneck,output_size,curr_size,target_output_size 641 10201 662185 88200
# bottleneck,output_size,curr_size,target_output_size 642 10217 663209 88200
# bottleneck,output_size,curr_size,target_output_size 643 10233 664233 88200
# bottleneck,output_size,curr_size,target_output_size 644 10249 665257 88200
# bottleneck,output_size,curr_size,target_output_size 645 10265 666281 88200
# bottleneck,output_size,curr_size,target_output_size 646 10281 667305 88200
# bottleneck,output_size,curr_size,target_output_size 647 10297 668329 88200
# bottleneck,output_size,curr_size,target_output_size 648 10313 669353 88200
# bottleneck,output_size,curr_size,target_output_size 649 10329 670377 88200
# bottleneck,output_size,curr_size,target_output_size 650 10345 671401 88200
# bottleneck,output_size,curr_size,target_output_size 651 10361 672425 88200
# bottleneck,output_size,curr_size,target_output_size 652 10377 673449 88200
# bottleneck,output_size,curr_size,target_output_size 653 10393 674473 88200
# bottleneck,output_size,curr_size,target_output_size 654 10409 675497 88200
# ...
#               (0): ConvLayer(
#                 (filter): Conv1d(256, 256, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#               )
#             )
#             (post_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(256, 512, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(64, 512, eps=1e-05, affine=True)
#               )
#             )
#             (downconv): Resample1d()
#           )
#           (4): DownsamplingBlock(
#             (pre_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(512, 512, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(64, 512, eps=1e-05, affine=True)
#               )
#             )
#             (post_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(512, 1024, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(128, 1024, eps=1e-05, affine=True)
#               )
#             )
#             (downconv): Resample1d()
#           )
#         )
#         (upsampling_blocks): ModuleList(
#           (0): UpsamplingBlock(
#             (upconv): Resample1d()
#             (pre_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(1024, 512, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(64, 512, eps=1e-05, affine=True)
#               )
#             )
#             (post_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(1024, 512, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(64, 512, eps=1e-05, affine=True)
#               )
#             )
#           )
#           (1): UpsamplingBlock(
#             (upconv): Resample1d()
#             (pre_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(512, 256, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#               )
#             )
#             (post_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(512, 256, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#               )
#             )
#           )
#         )
#         (bottlenecks): ModuleList(
#           (0): ConvLayer(
#             (filter): Conv1d(1024, 1024, kernel_size=(5,), stride=(1,))
#             (norm): GroupNorm(128, 1024, eps=1e-05, affine=True)
#           )
#         )
#         (output_conv): Conv1d(256, 2, kernel_size=(1,), stride=(1,))
#       )
#       (drums): Module(
#         (downsampling_blocks): ModuleList(
#           (0): DownsamplingBlock(
#             (pre_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(2, 32, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(4, 32, eps=1e-05, affine=True)
#               )
#             )
#             (post_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(32, 64, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#               )
#             )
#             (downconv): Resample1d()
#           )
#           (1): DownsamplingBlock(
#             (pre_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(64, 64, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#               )
#             )
#             (post_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(64, 128, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(16, 128, eps=1e-05, affine=True)
#               )
#             )
#             (downconv): Resample1d()
#           )
#           (2): DownsamplingBlock(
#             (pre_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(128, 128, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(16, 128, eps=1e-05, affine=True)
#               )
#             )
#             (post_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(128, 256, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#               )
#             )
#             (downconv): Resample1d()
#           )
#           (3): DownsamplingBlock(
#             (pre_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(256, 256, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#               )
#             )
#             (post_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(256, 512, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(64, 512, eps=1e-05, affine=True)
#               )
#             )
#             (downconv): Resample1d()
#           )
#           (4): DownsamplingBlock(
#             (pre_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(512, 512, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(64, 512, eps=1e-05, affine=True)
#               )
#             )
#             (post_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(512, 1024, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(128, 1024, eps=1e-05, affine=True)
#               )
#             )
#             (downconv): Resample1d()
#           )
#         )
#         (upsampling_blocks): ModuleList(
#           (0): UpsamplingBlock(
#             (upconv): Resample1d()
#             (pre_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(1024, 512, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(64, 512, eps=1e-05, affine=True)
#               )
#             )
#             (post_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(1024, 512, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(64, 512, eps=1e-05, affine=True)
#               )
#             )
#           )
#           (1): UpsamplingBlock(
#             (upconv): Resample1d()
#             (pre_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(512, 256, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#               )
#             )
#             (post_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(512, 256, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#               )
#             )
#           )
#         )
#         (bottlenecks): ModuleList(
#           (0): ConvLayer(
#             (filter): Conv1d(1024, 1024, kernel_size=(5,), stride=(1,))
#             (norm): GroupNorm(128, 1024, eps=1e-05, affine=True)
#           )
#         )
#         (output_conv): Conv1d(256, 2, kernel_size=(1,), stride=(1,))
#       )
#       (other): Module(
#         (downsampling_blocks): ModuleList(
#           (0): DownsamplingBlock(
#             (pre_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(2, 32, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(4, 32, eps=1e-05, affine=True)
#               )
#             )
#             (post_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(32, 64, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#               )
#             )
#             (downconv): Resample1d()
#           )
#           (1): DownsamplingBlock(
#             (pre_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(64, 64, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#               )
#             )
#             (post_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(64, 128, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(16, 128, eps=1e-05, affine=True)
#               )
#             )
#             (downconv): Resample1d()
#           )
#           (2): DownsamplingBlock(
#             (pre_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(128, 128, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(16, 128, eps=1e-05, affine=True)
#               )
#             )
#             (post_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(128, 256, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#               )
#             )
#             (downconv): Resample1d()
#           )
#           (3): DownsamplingBlock(
#             (pre_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(256, 256, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#               )
#             )
#             (post_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(256, 512, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(64, 512, eps=1e-05, affine=True)
#               )
#             )
#             (downconv): Resample1d()
#           )
#           (4): DownsamplingBlock(
#             (pre_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(512, 512, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(64, 512, eps=1e-05, affine=True)
#               )
#             )
#             (post_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(512, 1024, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(128, 1024, eps=1e-05, affine=True)
#               )
#             )
#             (downconv): Resample1d()
#           )
#         )
#         (upsampling_blocks): ModuleList(
#           (0): UpsamplingBlock(
#             (upconv): Resample1d()
#             (pre_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(1024, 512, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(64, 512, eps=1e-05, affine=True)
#               )
#             )
#             (post_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(1024, 512, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(64, 512, eps=1e-05, affine=True)
#               )
#             )
#           )
#           (1): UpsamplingBlock(
#             (upconv): Resample1d()
#             (pre_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(512, 256, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#               )
#             )
#             (post_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(512, 256, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#               )
#             )
#           )
#         )
#         (bottlenecks): ModuleList(
#           (0): ConvLayer(
#             (filter): Conv1d(1024, 1024, kernel_size=(5,), stride=(1,))
#             (norm): GroupNorm(128, 1024, eps=1e-05, affine=True)
#           )
#         )
#         (output_conv): Conv1d(256, 2, kernel_size=(1,), stride=(1,))
#       )
#       (vocals): Module(
#         (downsampling_blocks): ModuleList(
#           (0): DownsamplingBlock(
#             (pre_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(2, 32, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(4, 32, eps=1e-05, affine=True)
#               )
#             )
#             (post_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(32, 64, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#               )
#             )
#             (downconv): Resample1d()
#           )
#           (1): DownsamplingBlock(
#             (pre_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(64, 64, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#               )
#             )
#             (post_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(64, 128, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(16, 128, eps=1e-05, affine=True)
#               )
#             )
#             (downconv): Resample1d()
#           )
#           (2): DownsamplingBlock(
#             (pre_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(128, 128, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(16, 128, eps=1e-05, affine=True)
#               )
#             )
#             (post_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(128, 256, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#               )
#             )
#             (downconv): Resample1d()
#           )
#           (3): DownsamplingBlock(
#             (pre_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(256, 256, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#               )
#             )
#             (post_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(256, 512, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(64, 512, eps=1e-05, affine=True)
#               )
#             )
#             (downconv): Resample1d()
#           )
#           (4): DownsamplingBlock(
#             (pre_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(512, 512, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(64, 512, eps=1e-05, affine=True)
#               )
#             )
#             (post_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(512, 1024, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(128, 1024, eps=1e-05, affine=True)
#               )
#             )
#             (downconv): Resample1d()
#           )
#         )
#         (upsampling_blocks): ModuleList(
#           (0): UpsamplingBlock(
#             (upconv): Resample1d()
#             (pre_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(1024, 512, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(64, 512, eps=1e-05, affine=True)
#               )
#             )
#             (post_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(1024, 512, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(64, 512, eps=1e-05, affine=True)
#               )
#             )
#           )
#           (1): UpsamplingBlock(
#             (upconv): Resample1d()
#             (pre_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(512, 256, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#               )
#             )
#             (post_shortcut_convs): ModuleList(
#               (0): ConvLayer(
#                 (filter): Conv1d(512, 256, kernel_size=(5,), stride=(1,))
#                 (norm): GroupNorm(32, 256, eps=1e-05, affine=True)
#               )
#             )
#           )
#         )
#         (bottlenecks): ModuleList(
#           (0): ConvLayer(
#             (filter): Conv1d(1024, 1024, kernel_size=(5,), stride=(1,))
#             (norm): GroupNorm(128, 1024, eps=1e-05, affine=True)
#           )
#         )
#         (output_conv): Conv1d(256, 2, kernel_size=(1,), stride=(1,))
#       )
#     )
#   )
# )
# parameter count:  68397448

# %%
4**(4)
# Out:
# 256

# %%
# Using valid convolutions with 22588073 inputs and 88201 outputs

22588073/97961
# Out:
# 230.58230316146222

# %%
module = model.waveunets[[k for k in model.waveunets.keys()][0]]

# %%
# module.upsampling_blocks

# %%
"""self.strides = 2
self.sr = 22050
self.levels = 12"""

class Parameters:
    def __init__(self):
        self.cuda = True
        self.num_workers = 1
        self.features = 32
        self.log_dir = "./logs/waveunet"
        self.dataset_dir = "/mnt/windaten/Datasets/MUSDB18HQ"
        self.hdf_dir = "hdf"
        self.checkpoint_dir = "checkpoints/waveunet"
#         self.load_model = "waveunet/model"
        self.load_model = None
        self.lr = 1e-3
        self.min_lr = 5e-5
        self.cycles = 2
        self.batch_size = 4
        self.levels = 12
        self.depth = 1
        self.sr = 22050
        self.channels = 2
        self.kernel_size = 5
        self.output_size = 2.0
        self.strides = 2
        self.patience = 20
        self.example_freq = 200
        self.loss = "L1"
        self.conv_type = "gn"
        self.res = "fixed"
        self.separate = 1
        self.feature_growth = "double"
        self.input = "audio_examples/Cristina Vane - So Easy/mix.mp3"
        self.output = "./out"

# %%
# train.py
"""target_outputs = 20"""


import argparse
import os
import time

import torch
import pickle
import numpy as np

from torch.utils.tensorboard import SummaryWriter
from torch.optim import Adam
from tqdm import tqdm

import utils
from data import get_musdb_folds, SeparationDataset, random_amplify, crop
# from test import evaluate, validate
# from waveunet import Waveunet

args = Parameters()

INSTRUMENTS = ["bass"]
NUM_INSTRUMENTS = len(INSTRUMENTS)

#torch.backends.cudnn.benchmark=True # This makes dilated conv much faster for CuDNN 7.5

# MODEL
num_features = [args.features*i for i in range(1, args.levels+1)] if args.feature_growth == "add" else \
               [args.features*2**i for i in range(0, args.levels)]
target_outputs = int(args.output_size * args.sr)
# target_outputs = int(20)


model = Waveunet_ctc(args.channels, num_features, args.channels, INSTRUMENTS, kernel_size=args.kernel_size,
                 target_output_size=target_outputs, depth=args.depth, strides=args.strides,
                 conv_type=args.conv_type, res=args.res, separate=args.separate)

if args.cuda:
    model = utils.DataParallel(model)
    print("move model to gpu")
    model.cuda()
    
print('model: ', model)
print('parameter count: ', str(sum(p.numel() for p in model.parameters())))

writer = SummaryWriter(args.log_dir)
# Out:
# module.downsampling_blocks.append

# %%
layer 9
num_channels[0],num_channels[-2-i] 32 32
Using valid convolutions with 49401 inputs and 44297 outputs

# %%
# test.py
import museval
from tqdm import tqdm

import utils

import numpy as np
import torch

from utils import compute_loss

def predict(audio, model):
    if isinstance(audio, torch.Tensor):
        is_cuda = audio.is_cuda()
        audio = audio.detach().cpu().numpy()
        return_mode = "pytorch"
    else:
        return_mode = "numpy"

    expected_outputs = audio.shape[1]

    # Pad input if it is not divisible in length by the frame shift number
    output_shift = model.shapes["output_frames"]
    pad_back = audio.shape[1] % output_shift
    pad_back = 0 if pad_back == 0 else output_shift - pad_back
    if pad_back > 0:
        audio = np.pad(audio, [(0,0), (0, pad_back)], mode="constant", constant_values=0.0)

    target_outputs = audio.shape[1]
    outputs = {key: np.zeros(audio.shape, np.float32) for key in model.instruments}

    # Pad mixture across time at beginning and end so that neural network can make prediction at the beginning and end of signal
    pad_front_context = model.shapes["output_start_frame"]
    pad_back_context = model.shapes["input_frames"] - model.shapes["output_end_frame"]
    audio = np.pad(audio, [(0,0), (pad_front_context, pad_back_context)], mode="constant", constant_values=0.0)

    # Iterate over mixture magnitudes, fetch network prediction
    with torch.no_grad():
        for target_start_pos in range(0, target_outputs, model.shapes["output_frames"]):

            # Prepare mixture excerpt by selecting time interval
            curr_input = audio[:, target_start_pos:target_start_pos + model.shapes["input_frames"]] # Since audio was front-padded input of [targetpos:targetpos+inputframes] actually predicts [targetpos:targetpos+outputframes] target range

            # Convert to Pytorch tensor for model prediction
            curr_input = torch.from_numpy(curr_input).unsqueeze(0)

            # Predict
            for key, curr_targets in utils.compute_output(model, curr_input).items():
                outputs[key][:,target_start_pos:target_start_pos+model.shapes["output_frames"]] = curr_targets.squeeze(0).cpu().numpy()

    # Crop to expected length (since we padded to handle the frame shift)
    outputs = {key : outputs[key][:,:expected_outputs] for key in outputs.keys()}

    if return_mode == "pytorch":
        outputs = torch.from_numpy(outputs)
        if is_cuda:
            outputs = outputs.cuda()
    return outputs

def predict_song(args, audio_path, model):
    model.eval()

    # Load mixture in original sampling rate
    mix_audio, mix_sr = utils.load(audio_path, sr=None, mono=False)
    mix_channels = mix_audio.shape[0]
    mix_len = mix_audio.shape[1]

    # Adapt mixture channels to required input channels
    if args.channels == 1:
        mix_audio = np.mean(mix_audio, axis=0, keepdims=True)
    else:
        if mix_channels == 1: # Duplicate channels if input is mono but model is stereo
            mix_audio = np.tile(mix_audio, [args.channels, 1])
        else:
            assert(mix_channels == args.channels)

    # resample to model sampling rate
    mix_audio = utils.resample(mix_audio, mix_sr, args.sr)

    sources = predict(mix_audio, model)

    # Resample back to mixture sampling rate in case we had model on different sampling rate
    sources = {key : utils.resample(sources[key], args.sr, mix_sr) for key in sources.keys()}

    # In case we had to pad the mixture at the end, or we have a few samples too many due to inconsistent down- and upsamṕling, remove those samples from source prediction now
    for key in sources.keys():
        diff = sources[key].shape[1] - mix_len
        if diff > 0:
            print("WARNING: Cropping " + str(diff) + " samples")
            sources[key] = sources[key][:, :-diff]
        elif diff < 0:
            print("WARNING: Padding output by " + str(diff) + " samples")
            sources[key] = np.pad(sources[key], [(0,0), (0, -diff)], "constant", 0.0)

        # Adapt channels
        if mix_channels > args.channels:
            assert(args.channels == 1)
            # Duplicate mono predictions
            sources[key] = np.tile(sources[key], [mix_channels, 1])
        elif mix_channels < args.channels:
            assert(mix_channels == 1)
            # Reduce model output to mono
            sources[key] = np.mean(sources[key], axis=0, keepdims=True)

        sources[key] = np.asfortranarray(sources[key]) # So librosa does not complain if we want to save it

    return sources

def evaluate(args, dataset, model, instruments):
    perfs = list()
    model.eval()
    with torch.no_grad():
        for example in dataset:
            print("Evaluating " + example["mix"])

            # Load source references in their original sr and channel number
            target_sources = np.stack([utils.load(example[instrument], sr=None, mono=False)[0].T for instrument in instruments])

            # Predict using mixture
            pred_sources = predict_song(args, example["mix"], model)
            pred_sources = np.stack([pred_sources[key].T for key in instruments])

            # Evaluate
            SDR, ISR, SIR, SAR, _ = museval.metrics.bss_eval(target_sources, pred_sources)
            song = {}
            for idx, name in enumerate(instruments):
                song[name] = {"SDR" : SDR[idx], "ISR" : ISR[idx], "SIR" : SIR[idx], "SAR" : SAR[idx]}
            perfs.append(song)

    return perfs


def validate(args, model, criterion, test_data):
    # PREPARE DATA
    dataloader = torch.utils.data.DataLoader(test_data,
                                             batch_size=args.batch_size,
                                             shuffle=False,
                                             num_workers=args.num_workers)

    # VALIDATE
    model.eval()
    total_loss = 0.
    with tqdm(total=len(test_data) // args.batch_size) as pbar, torch.no_grad():
        for example_num, (x, targets) in enumerate(dataloader):
            if args.cuda:
                x = x.cuda()
                for k in list(targets.keys()):
                    targets[k] = targets[k].cuda()

            _, avg_loss = compute_loss(model, x, targets, criterion)

            total_loss += (1. / float(example_num + 1)) * (avg_loss - total_loss)

            pbar.set_description("Current loss: " + str(total_loss))
            pbar.update(1)

    return total_loss

# %%
import os 
args = Parameters()
os.makedirs(args.output, exist_ok=True)

# %%
# fun play
audio_path = args.input
mix_audio, mix_sr = utils.load(audio_path, sr=None, mono=False)
mix_channels = mix_audio.shape[0]
mix_len = mix_audio.shape[1]
print(mix_audio.shape)
# Out:
# /root/anaconda3/envs/waveunet/lib/python3.6/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# (2, 1323000)

# %%
# predict.py

# %%
import argparse
import os
import utils

# from test import predict_song
# import test
from waveunet import Waveunet

# parser = argparse.ArgumentParser()
# parser.add_argument('--cuda', action='store_true',
#                     help='use CUDA (default: False)')
# parser.add_argument('--features', type=int, default=32,
#                     help='# of feature channels per layer')
# parser.add_argument('--load_model', type=str,
#                     help='Reload a previously trained model')
# parser.add_argument('--batch_size', type=int, default=4,
#                     help="Batch size")
# parser.add_argument('--levels', type=int, default=6,
#                     help="Number DS/US blocks")
# parser.add_argument('--depth', type=int, default=1,
#                     help="Number of convs per block")
# parser.add_argument('--sr', type=int, default=44100,
#                     help="Sampling rate")
# parser.add_argument('--channels', type=int, default=2,
#                     help="Number of input audio channels")
# parser.add_argument('--kernel_size', type=int, default=5,
#                     help="Filter width of kernels. Has to be an odd number")
# parser.add_argument('--output_size', type=float, default=2.0,
#                     help="Output duration")
# parser.add_argument('--strides', type=int, default=4,
#                     help="Strides in Waveunet")
# parser.add_argument('--conv_type', type=str, default="gn",
#                     help="Type of convolution (normal, BN-normalised, GN-normalised): normal/bn/gn")
# parser.add_argument('--res', type=str, default="fixed",
#                     help="Resampling strategy: fixed sinc-based lowpass filtering or learned conv layer: fixed/learned")
# parser.add_argument('--separate', type=int, default=1,
#                     help="Train separate model for each source (1) or only one (0)")
# parser.add_argument('--feature_growth', type=str, default="double",
#                     help="How the features in each layer should grow, either (add) the initial number of features each time, or multiply by 2 (double)")

# parser.add_argument('--input', type=str, default=os.path.join("audio_examples", "Cristina Vane - So Easy", "mix.mp3"),
#                     help="Path to input mixture to be separated")
# parser.add_argument('--output', type=str, default=None, help="Output path (same folder as input path if not set)")

# args = parser.parse_args()

INSTRUMENTS = ["bass", "drums", "other", "vocals"]
NUM_INSTRUMENTS = len(INSTRUMENTS)

# MODEL
num_features = [args.features*i for i in range(1, args.levels+1)] if args.feature_growth == "add" else \
               [args.features*2**i for i in range(0, args.levels)]
target_outputs = int(args.output_size * args.sr)
model = Waveunet(args.channels, num_features, args.channels, INSTRUMENTS, kernel_size=args.kernel_size,
                 target_output_size=target_outputs, depth=args.depth, strides=args.strides,
                 conv_type=args.conv_type, res=args.res, separate=args.separate)

if args.cuda:
    model = utils.DataParallel(model)
    print("move model to gpu")
    model.cuda()

print("Loading model from checkpoint " + str(args.load_model))
state = utils.load_model(model, None, args.load_model)

preds = predict_song(args, args.input, model)

output_folder = os.path.dirname(args.input) if args.output is None else args.output
for inst in preds.keys():
    utils.write_wav(os.path.join(output_folder, os.path.basename(args.input) + "_" + inst + ".wav"), preds[inst], args.sr)
# Out:
# Using valid convolutions with 97961 inputs and 88409 outputs
# move model to gpu
# Loading model from checkpoint waveunet/model
# /root/anaconda3/envs/waveunet/lib/python3.6/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')

# %%
model.shapes["output_frames"]
# Out:
# 88409

# %%
pad_front_context = model.shapes["output_start_frame"]
pad_back_context = model.shapes["input_frames"] - model.shapes["output_end_frame"]
print(pad_front_context, pad_back_context)
print(model.shapes["input_frames"] , model.shapes["output_end_frame"])
print(model.shapes["input_frames"] - model.shapes["output_frames"])
# Out:
# 4776 4776
# 97961 93185
# 9552

# %%
audio = mix_audio
print(audio.shape)
expected_outputs = audio.shape[1]

# Pad input if it is not divisible in length by the frame shift number
output_shift = model.shapes["output_frames"]
pad_back = audio.shape[1] % output_shift
pad_back = 0 if pad_back == 0 else output_shift - pad_back
if pad_back > 0:
    audio = np.pad(audio, [(0,0), (0, pad_back)], mode="constant", constant_values=0.0)
print(audio.shape)
target_outputs = audio.shape[1]
outputs = {key: np.zeros(audio.shape, np.float32) for key in model.instruments}

# Pad mixture across time at beginning and end so that neural network can make prediction at the beginning and end of signal
pad_front_context = model.shapes["output_start_frame"]
pad_back_context = model.shapes["input_frames"] - model.shapes["output_end_frame"]
audio = np.pad(audio, [(0,0), (pad_front_context, pad_back_context)], mode="constant", constant_values=0.0)
print(audio.shape)
print(audio.shape[1]% output_shift)
# Out:
# (2, 1323000)
# (2, 1326135)
# (2, 1335687)
# 9552
